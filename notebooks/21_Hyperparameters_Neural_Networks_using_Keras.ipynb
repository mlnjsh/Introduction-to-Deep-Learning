# %% [markdown]
# # Steps to solve Emergency vs Non-Emergency vehicle classification problem
#
# <ol>1. Loading the dataset</ol>
# <ol>2. Pre-processing the data</ol>
# <ol>3. Creating training and validation set</ol>
# <ol>4. Defining the model architecture</ol>
# <ol>5. Compiling the model</ol>
# <ol>6. Training the model</ol>
# <ol>7. Evaluating model performance</ol>

# %% [markdown]
# ## 1. Loading the dataset

# %%
# import necessary libraries and functions
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential

from sklearn.model_selection import train_test_split

# %%
# reading the csv file
data = pd.read_csv('Dataset/emergency_classification.csv')

# %%
# create random number generator
seed = 42
rng = np.random.RandomState(seed)

# %%
# looking at first five rows of the data
data.head()
# Out:
#   image_names  emergency_or_not
# 0       0.jpg                 1
# 1       1.jpg                 1
# 2       2.jpg                 1
# 3       3.jpg                 1
# 4       4.jpg                 1

# %%
# distribution of classes in the dataset
data['emergency_or_not'].value_counts()
# Out:
# emergency_or_not
# 0    1361
# 1     991
# Name: count, dtype: int64

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('Dataset/images/' + img_name)
    # saving each image in the list
    X.append(img)

# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %%
# shape of the image
X.shape
# Out:
# (2352, 224, 224, 3)

# %%
# visualizing images
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(X[i*400])
    ax[i].axis('off')

# %% [markdown]
# ## 2. Pre-processing the data

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (2352, 150528)

# %%
# minimum and maximum pixel values of images
X.min(), X.max()
# Out:
# (0, 255)

# %%
# normalizing the pixel values
X = X / X.max()

# %%
# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## 3. Creating training and validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((1646, 150528), (1646,)), ((706, 150528), (706,)))

# %% [markdown]
# ## 4. Defining the model architecture

# %%
X_train.shape[1]
# Out:
# 150528

# %%
# defining the architecture of the model
model=Sequential()
model.add(InputLayer(shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 100)                 │      15,052,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,053,001 (57.42 MB)
#  Trainable params: 15,053,001 (57.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 5. Compiling the model

# %%
# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# - total training images = 1646
# - batch 128
# - 1 epoch = 1646/128 iterations
#
# ### Iterations per epoch:
# $
# \text{Iterations per epoch} = \frac{\text{Total training images}}{\text{Batch size}}
# = \frac{1646}{128} = 12.86 \approx 13
# $

# %% [markdown]
# ## 6. Training the model

# %%
# training the model
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.5759 - loss: 0.9429 - val_accuracy: 0.5793 - val_loss: 0.6620
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.6527 - loss: 0.6325 - val_accuracy: 0.6020 - val_loss: 0.6543
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.6460 - loss: 0.6365 - val_accuracy: 0.6303 - val_loss: 0.6309
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.7756 - loss: 0.4688 - val_accuracy: 0.7195 - val_loss: 0.5288
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.8226 - loss: 0.4247 - val_accuracy: 0.7167 - val_loss: 0.5305
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.8080 - loss: 0.4586 - val_accuracy: 0.7224 - val_loss: 0.5454
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.7915 - loss: 0.4579 - val_accuracy: 0.7181 - val_loss: 0.5285
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.7607 - loss: 0.4998 - val_accuracy: 0.7252 - val_loss: 0.5357
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.8098 - loss: 0.4212 - val_accuracy: 0.7082 - val_loss: 0.5413
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.8055 - loss: 0.4427 - val_accuracy: 0.6997 - val_loss: 0.5714
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.7982 - loss: 0.4517 - val_accuracy: 0.7224 - val_loss: 0.5287
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.8177 - loss: 0.4239 - val_accuracy: 0.7238 - val_loss: 0.5338

# %% [markdown]
# ## 7. Evaluating model performance

# %%
# getting predictions in the form of class as well as probabilities
prediction= model.predict(X_valid)[:,0]
predictions = np.where(prediction < 0.5, 0, 1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# accuracy on validation set
from sklearn.metrics import accuracy_score
print('Accuracy on validation set:', accuracy_score(y_valid, predictions), '%')
# Out:
# Accuracy on validation set: 0.7237960339943342 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
data.image_names.values
# Out:
# array(['0.jpg', '1.jpg', '2.jpg', ..., '2349.jpg', '2350.jpg', '2351.jpg'],
#       dtype=object)

# %%
# pull out the original images from the data which correspond to the validation data
_, valid_vehicles, _, valid_y = train_test_split(data.image_names.values, y, test_size=0.3, random_state=seed)

# get a random index to plot image randomly
index = rng.choice(range(len(valid_vehicles))) #will provide one value

# get the corresponding image name and probability
img_name = valid_vehicles[index]
prob = (prediction * 100).astype(int)[index]

# read the image
img = plt.imread('Dataset/images/' + img_name)

# print probability and actual class
print('Model is', prob , '% sure that it is emergency')
print('And actual class is ', valid_y[index])

# plot image
plt.imshow(img)
# Out:
# Model is 8 % sure that it is emergency
# And actual class is  0

# %% [markdown]
# # Hyperparameter tuning of neural networks

# %% [markdown]
# <ol>1. change activation function of hidden layer</ol>
# <ol>2. increase hidden neurons</ol>
# <ol>3. increase hidden layers</ol>
# <ol>4. increase number of epochs</ol>
# <ol>5. change optimizer</ol>

# %% [markdown]
# ### 1. Changing activation function of hidden layer

# %%
# using relu as activation function in hidden layer
model=Sequential()
model.add(InputLayer(shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 100)                 │      15,052,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,053,001 (57.42 MB)
#  Trainable params: 15,053,001 (57.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# training the model for 50 epochs
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.5440 - loss: 2.2910 - val_accuracy: 0.5609 - val_loss: 0.6681
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5949 - loss: 0.6554 - val_accuracy: 0.5609 - val_loss: 0.6632
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.6162 - loss: 0.6488 - val_accuracy: 0.6530 - val_loss: 0.6416
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.6529 - loss: 0.6306 - val_accuracy: 0.6671 - val_loss: 0.6311
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.6609 - loss: 0.6265 - val_accuracy: 0.6714 - val_loss: 0.6140
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.6763 - loss: 0.6214 - val_accuracy: 0.6771 - val_loss: 0.6099
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.6463 - loss: 0.6251 - val_accuracy: 0.6912 - val_loss: 0.6003
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6388 - loss: 0.6248 - val_accuracy: 0.6246 - val_loss: 0.6357
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.6447 - loss: 0.6439 - val_accuracy: 0.6629 - val_loss: 0.6036
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.6740 - loss: 0.6291 - val_accuracy: 0.5779 - val_loss: 0.7433
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.5937 - loss: 0.6759 - val_accuracy: 0.5609 - val_loss: 0.6869
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.5947 - loss: 0.6750 - val_accuracy: 0.5609 - val_loss: 0.6867
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5909 - loss: 0.6765 - val_accuracy: 0.5609 - val_loss: 0.6867
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.5787 - loss: 0.6803 - val_accuracy: 0.5609 - val_loss: 0.6874
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.5915 - loss: 0.6766 - val_accuracy: 0.5609 - val_loss: 0.6869
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.5841 - loss: 0.6791 - val_accuracy: 0.5609 - val_loss: 0.6877
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6040 - loss: 0.6713 - val_accuracy: 0.5609 - val_loss: 0.6860
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.5866 - loss: 0.6772 - val_accuracy: 0.5609 - val_loss: 0.6865
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.5887 - loss: 0.6775 - val_accuracy: 0.5609 - val_loss: 0.6870
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.5970 - loss: 0.6742 - val_accuracy: 0.5609 - val_loss: 0.6872

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, np.where(model.predict(X_valid)[:, 0] < 0.5, 0, 1)))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Accuracy on validation set: 0.5609065155807366

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 5. Changing the optimizer

# %%
# importing adam optimizer from keras optimizer module
from keras.optimizers import Adam

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(learning_rate=1e-5)

# %%
# change optimizer
model=Sequential()

model.add(InputLayer(shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_25 (Dense)                     │ (None, 100)                 │      15,052,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,063,101 (57.46 MB)
#  Trainable params: 15,063,101 (57.46 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = model.fit(X_train, y_train, epochs=100, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.5689 - loss: 0.6838 - val_accuracy: 0.5609 - val_loss: 0.6844
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.5765 - loss: 0.6798 - val_accuracy: 0.5609 - val_loss: 0.6833
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.5971 - loss: 0.6696 - val_accuracy: 0.5609 - val_loss: 0.6807
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.5826 - loss: 0.6760 - val_accuracy: 0.5609 - val_loss: 0.6842
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.5961 - loss: 0.6735 - val_accuracy: 0.5609 - val_loss: 0.6836
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.5850 - loss: 0.6759 - val_accuracy: 0.5609 - val_loss: 0.6825
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.5723 - loss: 0.6798 - val_accuracy: 0.5609 - val_loss: 0.6820
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.5712 - loss: 0.6798 - val_accuracy: 0.5609 - val_loss: 0.6858
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.5796 - loss: 0.6792 - val_accuracy: 0.5609 - val_loss: 0.6844
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.5904 - loss: 0.6753 - val_accuracy: 0.5609 - val_loss: 0.6849
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.5684 - loss: 0.6829 - val_accuracy: 0.5609 - val_loss: 0.6858
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.5884 - loss: 0.6761 - val_accuracy: 0.5609 - val_loss: 0.6863
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.5909 - loss: 0.6765 - val_accuracy: 0.5609 - val_loss: 0.6861
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.5824 - loss: 0.6791 - val_accuracy: 0.5609 - val_loss: 0.6851
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.6005 - loss: 0.6717 - val_accuracy: 0.5609 - val_loss: 0.6856
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.5977 - loss: 0.6747 - val_accuracy: 0.5609 - val_loss: 0.6861
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.5894 - loss: 0.6775 - val_accuracy: 0.5609 - val_loss: 0.6861
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.6008 - loss: 0.6737 - val_accuracy: 0.5609 - val_loss: 0.6862
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.5857 - loss: 0.6784 - val_accuracy: 0.5609 - val_loss: 0.6862
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.5866 - loss: 0.6779 - val_accuracy: 0.5609 - val_loss: 0.6852
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.5947 - loss: 0.6740 - val_accuracy: 0.5609 - val_loss: 0.6847
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.5878 - loss: 0.6755 - val_accuracy: 0.5609 - val_loss: 0.6851
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.5768 - loss: 0.6796 - val_accuracy: 0.5609 - val_loss: 0.6841
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.5928 - loss: 0.6739 - val_accuracy: 0.5609 - val_loss: 0.6844
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.