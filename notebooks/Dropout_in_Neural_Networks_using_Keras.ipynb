# %%
# %tensorflow_version 2.x

# %% [markdown]
# # Steps to solve Emergency vs Non-Emergency vehicle classification problem using Dropout
#
# <ol>1. Loading the dataset</ol>
# <ol>2. Pre-processing the data</ol>
# <ol>3. Creating training and validation set</ol>
# <ol>4. Defining the model architecture</ol>
# <ol> <ol>* Adding dropout layer(s) </ol></ol>
# <ol>5. Compiling the model</ol>
# <ol>6. Training the model using Dropout</ol>
# <ol>7. Evaluating model performance</ol>

# %% [markdown]
# ## 1. Loading the dataset

# %%
# import necessary libraries and functions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# importing layers from keras
from keras.layers import Dense, InputLayer
from keras.models import Sequential
# importing adam optimizer from keras optimizer module
from keras.optimizers import Adam

# train_test_split to create training and validation set
from sklearn.model_selection import train_test_split
# accuracy_score to calculate the accuracy of predictions
from sklearn.metrics import accuracy_score

# %%
# reading the csv file
data = pd.read_csv('Dataset/emergency_classification.csv')

# %%
# create random number generator
seed = 42
rng = np.random.RandomState(seed)

# %%
# looking at first five rows of the data
data.head()
# Out:
#   image_names  emergency_or_not
# 0       0.jpg                 1
# 1       1.jpg                 1
# 2       2.jpg                 1
# 3       3.jpg                 1
# 4       4.jpg                 1

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('Dataset/images/' + img_name)
    # saving each image in the list
    X.append(img)

# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %% [markdown]
# ## 2. Pre-processing the data

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (2352, 150528)

# %%
# normalizing the pixel values
X = X / X.max()

# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## 3. Creating training and validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((1646, 150528), (1646,)), ((706, 150528), (706,)))

# %% [markdown]
# ## 4. Defining the model architecture
#
# ### <ol>Adding dropout layer(s)</ol>

# %%
# importing the dropout layer
from keras.layers import Dropout

# %%
# defining the model architecture with dropout layer
model=Sequential()

model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dropout(rate=0.5))
model.add(Dense(100, activation='sigmoid'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# C:\Anaconda\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# ## 5. Compiling the model

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(learning_rate=1e-5)

# %%
# compiling the model

# defining loss as binary crossentropy
# defining optimizer as Adam
# defining metrics as accuracy

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

#
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.7209 - loss: 0.5596 - val_accuracy: 0.7125 - val_loss: 0.5538
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.7464 - loss: 0.5400 - val_accuracy: 0.7210 - val_loss: 0.5610
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.7404 - loss: 0.5432 - val_accuracy: 0.7139 - val_loss: 0.5624
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.7336 - loss: 0.5427 - val_accuracy: 0.7110 - val_loss: 0.5550
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.7452 - loss: 0.5339 - val_accuracy: 0.7153 - val_loss: 0.5565
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7527 - loss: 0.5284 - val_accuracy: 0.7153 - val_loss: 0.5527
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - accuracy: 0.7397 - loss: 0.5407 - val_accuracy: 0.7153 - val_loss: 0.5612
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - accuracy: 0.7301 - loss: 0.5651 - val_accuracy: 0.7125 - val_loss: 0.5614
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.7577 - loss: 0.5416 - val_accuracy: 0.7096 - val_loss: 0.5537
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - accuracy: 0.7663 - loss: 0.5251 - val_accuracy: 0.7096 - val_loss: 0.5526
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7514 - loss: 0.5207 - val_accuracy: 0.7139 - val_loss: 0.5589
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - accuracy: 0.7587 - loss: 0.5261 - val_accuracy: 0.7110 - val_loss: 0.5525
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7517 - loss: 0.5248 - val_accuracy: 0.7125 - val_loss: 0.5548
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.7482 - loss: 0.5380 - val_accuracy: 0.7210 - val_loss: 0.5494
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7488 - loss: 0.5287 - val_accuracy: 0.7096 - val_loss: 0.5638
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.7389 - loss: 0.5370 - val_accuracy: 0.7054 - val_loss: 0.5637
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7696 - loss: 0.5014 - val_accuracy: 0.7153 - val_loss: 0.5545
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.7597 - loss: 0.5165 - val_accuracy: 0.7139 - val_loss: 0.5502
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.7784 - loss: 0.5176 - val_accuracy: 0.7153 - val_loss: 0.5539
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.7569 - loss: 0.5155 - val_accuracy: 0.7125 - val_loss: 0.5511
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.7869 - loss: 0.5027 - val_accuracy: 0.7139 - val_loss: 0.5488
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - accuracy: 0.7287 - loss: 0.5490 - val_accuracy: 0.7096 - val_loss: 0.5584
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.7644 - loss: 0.5094 - val_accuracy: 0.7195 - val_loss: 0.5490
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7724 - loss: 0.5178 - val_accuracy: 0.7224 - val_loss: 0.5481
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.7660 - loss: 0.5099 - val_accuracy: 0.7153 - val_loss: 0.5512
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.7671 - loss: 0.5036 - val_accuracy: 0.7054 - val_loss: 0.5641
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7621 - loss: 0.5116 - val_accuracy: 0.7110 - val_loss: 0.5578
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7626 - loss: 0.5041 - val_accuracy: 0.7125 - val_loss: 0.5551
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7773 - loss: 0.5000 - val_accuracy: 0.7210 - val_loss: 0.5488
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - accuracy: 0.7711 - loss: 0.5067 - val_accuracy: 0.7139 - val_loss: 0.5438
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7561 - loss: 0.5110 - val_accuracy: 0.7068 - val_loss: 0.5614
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7686 - loss: 0.5069 - val_accuracy: 0.7054 - val_loss: 0.5542

# %% [markdown]
# ## 7. Evaluating model performance

# %%
y_pred = model.predict(X_valid)
y_pred = np.where(y_pred <0.3, 0, 1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, y_pred), '%')
# Out:
# Accuracy on validation set: 0.7138810198300283 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
